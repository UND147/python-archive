# %%
pip install pyautogui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyautogui

pyautogui.position()
# Out:
# Point(x=2883, y=358)

# %%
import pyautogui
import time

time.sleep(2)
pyautogui.position()
# Out:
# Point(x=2453, y=20)

# %%
import pyautogui
import time

time.sleep(2)
pyautogui.position()
# Out:
# Point(x=2889, y=392)

# %%
pyautogui.moveTo(2453, 20, duration=2) # 해당 좌표로 2초동안 이동

# %%
pyautogui.moveTo(2453, 20, duration=2)
pyautogui.click()
