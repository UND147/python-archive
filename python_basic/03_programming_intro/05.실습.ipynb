# %%
champName = "유미"
champLevel = 6
champHp = 950
champComment = "나랑 유미랑!"
print("이름-"+champName)
print("레벨-"+str(champLevel))
print("체력-",champHp)
print("대사-",champComment)
# Out:
# 이름-유미
# 레벨-6
# 체력- 950
# 대사- 나랑 유미랑!

# %%
name = input("포켓몬이름:")
print("받아라 몬스터볼~!",name,"넌 내꺼야!")
print(f"받아라 몬스터볼~! {name} 넌 내꺼야!")
# Out:
# 받아라 몬스터볼~! 파이리 넌 내꺼야!
# 받아라 몬스터볼~! 파이리 넌 내꺼야!

# %%
name = input("포켓몬 이름을 입력하세요:")
level = input("레벨을 입력하세요:")
print("[포켓몬 정보]")
print("이름:",name)
print("레벨:",level)
# Out:
# [포켓몬 정보]
# 이름: 이상해씨
# 레벨: 8
