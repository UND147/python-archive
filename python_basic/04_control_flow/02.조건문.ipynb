# %%
origin_pass = "1234"
input_pass = input()
if origin_pass == input_pass:
    print("로그인 성공")
elif input_pass == "":
    print("비밀번호를 입력하세요")
else:
    print("로그인 실패")
# Out:
# 비밀번호를 입력하세요

# %%
subscriber = input("현재 구독자 수를 입력하세요")
if int(subscriber)>=1000:
    print("수익 창출이 가능합니다!")
else:
    print("수익 창출이 불가능합니다!")
# Out:
# 수익 창출이 불가능합니다!

# %%
studyTime = input("공부시간을 입력하세요(시간):")
if int(studyTime)>=10:
    print("휴대폰 잠금이 해제 됩니다.")
elif int(studyTime)>=5:
    print("휴대폰을 30분간 사용가능합니다.")
else:
    print("휴대폰 사용이 불가능합니다.")
# Out:
# 휴대폰을 30분간 사용가능합니다.
