# %%
for i in range(3):
    print(f"{i+1}번 과제 시작")
    print("과제 완료")
# Out:
# 1번 과제 시작
# 과제 완료
# 2번 과제 시작
# 과제 완료
# 3번 과제 시작
# 과제 완료

# %%
for i in range(1, 4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(3):
    print("푸들")
# Out:
# 푸들
# 푸들
# 푸들

# %%
for i in range(3):
    print(f"{i+1}번째 강아지")
    print("강아지를 위한 장난감 준비 중")
    print("장난감 준비 완료")
    print("")
# Out:
# 1번째 강아지
# 강아지를 위한 장난감 준비 중
# 장난감 준비 완료
#
# 2번째 강아지
# 강아지를 위한 장난감 준비 중
# 장난감 준비 완료
#
# 3번째 강아지
# 강아지를 위한 장난감 준비 중
# 장난감 준비 완료

# %%
total = 0
for i in range(10):
    
    total += (i+1)
# for i in range(1, 11):
#     total += i
print(total)
# Out:
# 55

# %%
i = 0
while i<3:
    print("Hello")
    i += 1
# Out:
# Hello
# Hello
# Hello

# %%
dan = int(input("몇 단을 출력할까요?"))
for i in range(1, 10):
    print(f"{dan} * {i} = {dan*i}")
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45

# %%
i = 1
dan = int(input("몇 단을 출력할까요?"))
while i<10:
    print(f"{dan} * {i} = {dan*i}")
    i += 1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45

# %%
password = 1234
while True:
    inputPassword = int(input("비밀번호를 입력하세요 :"))
    if inputPassword == password:
        print("로그인 성공!")
        break
    else:
        print("로그인 실패!")
# Out:
# 로그인 실패!
# 로그인 실패!
# 로그인 실패!
# 로그인 성공!
